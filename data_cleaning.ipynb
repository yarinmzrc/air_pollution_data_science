# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')
df
# Out:
#                          city  Avg 2020  January February    March    April  \
# 0                Hotan, China     110.2    93.7    124.7    264.4    176.4
# 1            Ghaziabad, India     106.6   146.3    111.8     76.9       88
# 2          Bulandshahr, India      98.4   116.9     97.8     71.7     86.4
# 3     Bisrakh Jalalpur, India      96.0     130       99     70.2     82.4
# 4              Bhiwadi, India      95.5   100.7    102.3     81.4       66
# ...                       ...       ...      ...      ...      ...      ...
# 4445            Grantham, USA       5.6     5.5      6.7        4      3.6
# 4446               Utica, USA       5.6     7.7      6.9      4.5      3.3
# 4447          Bennington, USA       5.6     5.8      7.8      4.8      4.2
# 4448      Targinie, Australia       5.5       7      6.1      4.6      4.4
# 4449      Oatlands, Australia       5.5     9.3      2.5        3      4.7
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4450 entries, 0 to 4449
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   city       4450 non-null   object
#  1   Avg 2020   4450 non-null   float64
#  2   January    4450 non-null   object
#  3   February   4450 non-null   object
#  4   March      4450 non-null   object
#  5   April      4450 non-null   object
#  6   May        4450 non-null   object
#  7   June       4450 non-null   object
#  8   July       4450 non-null   object
#  9   August     4450 non-null   object
#  10  September  4450 non-null   object
#  11  October    4450 non-null   object
#  12  November   4450 non-null   object
#  13  December   4450 non-null   object
#  14  Avg 2019   4450 non-null   object
# dtypes: float64(1), object(14)
# memory usage: 521.6+ KB

# %%
cleaned_df = df.dropna()

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4450 entries, 0 to 4449
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   city       4450 non-null   object
#  1   Avg 2020   4450 non-null   float64
#  2   January    4450 non-null   object
#  3   February   4450 non-null   object
#  4   March      4450 non-null   object
#  5   April      4450 non-null   object
#  6   May        4450 non-null   object
#  7   June       4450 non-null   object
#  8   July       4450 non-null   object
#  9   August     4450 non-null   object
#  10  September  4450 non-null   object
#  11  October    4450 non-null   object
#  12  November   4450 non-null   object
#  13  December   4450 non-null   object
#  14  Avg 2019   4450 non-null   object
# dtypes: float64(1), object(14)
# memory usage: 556.2+ KB

# %%
#Our NaN data was as '-', here we are droping all rows that are with '-':
for column in cleaned_df:
    cleaned_df = cleaned_df[cleaned_df[column] != ' - ']

# %%
cleaned_df

# %% [markdown]
# #### Creating a new column that classifies avg2020 to groups by PM2.5 values:
# 1 = Good (10.1-12.0),
# 2 = Moderate (12.1-35.4),
# 3 = Unhealthy For Sensitive Groups (35.5-55.3),
# 4 = Unhealthy (55.4-150.3),
# 5 = Very Unhealthy(150.4-250.3).

# %%
bins = [0,10.1, 12.1, 35.5, 55.4, 150.4, 250.4]
labels = [1, 2, 3, 4, 5,6]
cleaned_df["Classify Groups"] = pd.cut(cleaned_df["Avg 2020"], bins, labels=labels)

# %%
cleaned_df.to_csv('cleaned_data.csv', encoding='utf-8', index=False)

# %%
cleaned_df
# Out:
#                      city  Avg 2020  January February    March    April  \
# 0            Hotan, China     110.2    93.7    124.7    264.4    176.4
# 1        Ghaziabad, India     106.6   146.3    111.8     76.9       88
# 2      Bulandshahr, India      98.4   116.9     97.8     71.7     86.4
# 4          Bhiwadi, India      95.5   100.7    102.3     81.4       66
# 5            Noida, India      94.3   131.6     99.2     65.5     76.6
# ...                   ...       ...      ...      ...      ...      ...
# 4445        Grantham, USA       5.6     5.5      6.7        4      3.6
# 4446           Utica, USA       5.6     7.7      6.9      4.5      3.3
# 4447      Bennington, USA       5.6     5.8      7.8      4.8      4.2
# 4448  Targinie, Australia       5.5       7      6.1      4.6      4.4
# 4449  Oatlands, Australia       5.5     9.3      2.5        3      4.7
#
#           May     June    July  August September  October November December  \
# ...

# %% [markdown]
# Now we are spliting the City and Country to 2 different columns and re-aranging the DataFrame,
# we want the country name to be beside the city name:

# %%
cleaned_df[['city', 'Country']] = cleaned_df['city'].str.split(', ', 1, expand=True)
cleaned_df
# Out:
#              city  Avg 2020  January February    March    April      May  \
# 0           Hotan     110.2    93.7    124.7    264.4    176.4    101.9
# 1       Ghaziabad     106.6   146.3    111.8     76.9       88     84.1
# 2     Bulandshahr      98.4   116.9     97.8     71.7     86.4     85.3
# 4         Bhiwadi      95.5   100.7    102.3     81.4       66     83.5
# 5           Noida      94.3   131.6     99.2     65.5     76.6     69.7
# ...           ...       ...      ...      ...      ...      ...      ...
# 4445     Grantham       5.6     5.5      6.7        4      3.6      3.6
# 4446        Utica       5.6     7.7      6.9      4.5      3.3      3.9
# 4447   Bennington       5.6     5.8      7.8      4.8      4.2      4.2
# 4448     Targinie       5.5       7      6.1      4.6      4.4      3.8
# 4449     Oatlands       5.5     9.3      2.5        3      4.7        6
#
#          June    July  August September  October November December Avg 2019  \
# ...

# %%
cleaned_df = cleaned_df[['city','Country','Avg 2020','January','February','March','April','May',
                         'June','July','August','September','October','November',
                         'December','Avg 2019','Classify Groups']]
cleaned_df
# Out:
#              city    Country  Avg 2020  January February    March    April  \
# 0           Hotan      China     110.2    93.7    124.7    264.4    176.4
# 1       Ghaziabad      India     106.6   146.3    111.8     76.9       88
# 2     Bulandshahr      India      98.4   116.9     97.8     71.7     86.4
# 4         Bhiwadi      India      95.5   100.7    102.3     81.4       66
# 5           Noida      India      94.3   131.6     99.2     65.5     76.6
# ...           ...        ...       ...      ...      ...      ...      ...
# 4445     Grantham        USA       5.6     5.5      6.7        4      3.6
# 4446        Utica        USA       5.6     7.7      6.9      4.5      3.3
# 4447   Bennington        USA       5.6     5.8      7.8      4.8      4.2
# 4448     Targinie  Australia       5.5       7      6.1      4.6      4.4
# 4449     Oatlands  Australia       5.5     9.3      2.5        3      4.7
#
#           May     June    July  August September  October November December  \
# ...

# %%
cleaned_df.to_csv('cleaned_data.csv', encoding='utf-8', index=False)
